# %% [markdown]
# # __BOX_NAME__
#
# <https://www.hackthebox.com/machines/__BOX_NAME__>

# %% [markdown]
# ## Port Scanning
#
# Add the mapping from `__TARGET_IP__` to `__BOX_HOST__` in `/etc/hosts`
#
# ```bash
# # TCP scanning
# sudo nmap -vv -sC -sV -T4 -A __TARGET_IP__
# ```

# %%
TARGET_IP = "__TARGET_IP__"
TARGET_HOST = "__BOX_HOST__"
OUTPUT_DIR = TARGET_HOST
CREDENTIALS: dict[str, str] = {}

# %%
from common import scan_ports

print("Scanning TCP ports for IP:", TARGET_HOST)
scan_ports(TARGET_HOST, top_ports=65535)
